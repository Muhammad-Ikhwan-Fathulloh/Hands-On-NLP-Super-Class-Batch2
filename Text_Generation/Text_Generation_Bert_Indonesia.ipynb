# %% [markdown]
# # Text Generation
#
# Link: https://github.com/cahya-wirawan/indonesian-language-models/tree/master/Transformers

# %%
import torch
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer, GPT2LMHeadModel

tokenizer = GPT2Tokenizer.from_pretrained("cahya/gpt2-small-indonesian-522M")

# add the EOS token as PAD token to avoid warnings
model = GPT2LMHeadModel.from_pretrained("cahya/gpt2-small-indonesian-522M", pad_token_id=tokenizer.eos_token_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/16.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/894k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/452k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/573 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/510M [00:00<?, ?B/s]

# %%
input_sentences = [
    'Alkisah pada jaman dahulu kala seekor babi tengah melintas di sebuah hutan belantara. Babi hutan itu sedang merasa kehausan di tengah panasnya terik matahari',
    'Cirebon adalah sebuah kota kecil di Jawa Barat dengan keindahannya yang melebihi kota Bandung',
    'Sriwijaya adalah salah satu kemaharajaan bahari yang pernah berdiri di pulau Sumatra dan banyak memberi pengaruh di Nusantara dengan daerah kekuasaan yang luas',
    'Pantai berpasir putih ini cukup populer akhir-akhir ini karena menawarkan pemandangan yang begitu eksotis, indah dan mempesona',
]

# %%
# We set the seed manualy for reproducible result
for i, sentence in enumerate(input_sentences):
    torch.manual_seed(1)
    input_ids = tokenizer.encode(sentence, return_tensors='pt')
    sample_output = model.generate(
        input_ids,
        do_sample=True,
        max_length=150,
        top_k=50,
        top_p=0.95
    )
    print("Output:\n" + 100 * '-')
    print("{}: {}".format(i, tokenizer.decode(sample_output[0], skip_special_tokens=True)))
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# 0: Alkisah pada jaman dahulu kala seekor babi tengah melintas di sebuah hutan belantara. Babi hutan itu sedang merasa kehausan di tengah panasnya terik matahari namun tiba-tiba ekornya berlumuran darah yang keluar dari telapak kaki babi. Dan seketika babi hutan itu pun tercium bau tidak sedap oleh lidah manusia.
# Akhirnya sang babi hutan pun menjadi santapan keluarga itu, dan mulai tidak sabar menunggu. Melihat babi hutan itu sedang berbaring terlelap, sang babi hutan terkejut. Ia heran saat ia teringat akan mimpinya, yaitu memijat babi hutan itu dengan air, ia menyadari bahwa ketika sedang marah, babi hutan itu tidak sadar bahwa sudah tidak sabar dan malu untuk melangkah.
# Ketika sang babi hutan kembali pulang dengan berjalan kaki, ia pun merasa ketakutan yang sama, ketika babi
# Output:
# ----------------------------------------------------------------------------------------------------
# 1: Cirebon adalah sebuah kota kecil di Jawa Barat dengan keindahannya yang melebihi kota Bandung. Kota Bandung terkenal dengan batiknya yang bernama batik "mande". Kota Bandung terkenal dengan julukan kota batik "Kota Batik", karena penduduknya kebanyakan berprofesi sebagai pembuat batik, sedangkan untuk kalangan menengah atau profesional, kota Bandung dikenal sebagai kota batik.
# Pada zaman dahulu, Bandung adalah sebuah kota pelabuhan. Namun, sebelum pemerintahan pemerintah Hindia Belanda berubah menjadi Kota Batavia yang menjadi ibu kota negara, Bandung masih merupakan kota kecil yang memiliki pusat pemerintahan yang besar.
# Dalam "Vorstenlanden op Java", tahun 1916, terdapat sebuah surat kabar bernama "Bataviasche Courant" yang di dalamnya memuat artikel-artikel tentang Hindia Belanda yang diterbitkan di Batavia. Isi surat kabar tersebut menyatakan bahwa:
# Output:
# ----------------------------------------------------------------------------------------------------
# 2: Sriwijaya adalah salah satu kemaharajaan bahari yang pernah berdiri di pulau Sumatra dan banyak memberi pengaruh di Nusantara dengan daerah kekuasaan yang luas di barat Pulau Jawa serta kepulauan Maluku dan Maluku yang menjadi daerah kekuasaan di pulau Sumatra. Pada akhir abad ke-13, Sriwijaya tidak lagi mengirim upeti, namun hanya memberikan upeti untuk memenuhi ambisinya menaklukkan wilayah-wilayah taklukan Dharmasraya.
# Pada permulaan abad ke-14, Sriwijaya telah menguasai daerah dataran tinggi, sedangkan kekuatan politiknya sudah mulai merosot. Sriwijaya akhirnya dikalahkan dan menjadi penguasa Sumatra yang mandiri di daratan Asia Tenggara, yang berada di bawah hegemoni Sriwijaya.
# Dalam "Nawana" disebutkan bahwa pada tahun 670 M, Indrawarman raja Sriwijaya menguasai wilayah Sumatra dengan pusat pemerintahannya di Palembang. Pada tahun yang sama, Indrawarman berangkat menyerang Jawa Timur
# Output:
# ----------------------------------------------------------------------------------------------------
# 3: Pantai berpasir putih ini cukup populer akhir-akhir ini karena menawarkan pemandangan yang begitu eksotis, indah dan mempesona. Pantai ini juga telah dijadikan lokasi pengambilan gambar iklan untuk daerah Serui, Ketapang dan Bandar Udara Ketapang.
# Ada beberapa fasilitas yang disediakan oleh pantai berpasir putih ini, yaitu:
# Lokasi wisata pantai berpasir putih ini pun cukup mudah dijangkau, karena pantai yang cukup bersih. Terdapat sekitar 100 unit mobil yang siap mengantar wisatawan ke pantai ini. Untuk akomodasi bagi pengunjung, Anda dapat memanfaatkan hotel di Pantai ini. Untuk masuk kesana anda dapat menggunakan kapal cepat dengan rute Surabaya – Banyuwangi – Malang – Jakarta dan sebaliknya untuk menuju ke Pantai Ketapang.
#
# Pantai Tanjung Layar merupakan salah satu objek wisata Pantai yang terletak di Kabupaten Sumenep, Jawa Timur. Pantai ini berada pada posisi
